# %% [markdown]
# <a href="https://colab.research.google.com/github/allyyaanr/2209116030_CRISP-DM_DEPLOYMENT/blob/main/2209116030_Allyya_Nur_Azizah_Tugas_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Technical specifications, ratings, and prices for 1000 laptops from Flipkart / Spesifikasi teknis, rating, dan harga 1000 laptop dari Flipkart**

# %% [markdown]
# #**Import Library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Algoritma C4.5
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Dataset ini dibuat untuk memberikan edukasi kepada customer seputar informasi tentang 1000 laptop yang tersedia di situs e-commerce Flipkart di India. Dataset ini memberikan pandangan komprehensif tentang pasar laptop di India dan dapat digunakan untuk analisis, penelitian, atau tujuan lainnya. Maka dari itu, dataset ini berguna untuk semua kalangan pengguna. Selain itu, dibuatnya dataset ini untuk menjadi patokan para customer sebelum membeli.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Dalam era digital saat ini, laptop menjadi alat penting untuk pekerjaan, pendidikan, dan hiburan sehingga customer laptop meningkat. Dataset ini membantu memberikan data-data Data-data yang diberikan mencakup spesifikasi teknis seperti jenis prosesor, ukuran RAM, kapasitas hard drive, ukuran dan resolusi layar, serta sistem operasi. Selain itu, dataset ini mencakup peringkat dan ulasan customer, serta informasi harga. Dengan dibuatnya dataset tersebut menguntungkan dan membantu customer sehinggan para customer tidak perlu khawatir lagi salah membeli laptop.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Penggalian data dari dataset ini memiliki sejumlah tujuan yang dirancang untuk memberikan edukasi mendalam tentang pasar laptop di India melalui pandangan teknis, ulasan pelanggan, dan faktor harga.
#
# Pertama, tujuan utama adalah membagi laptop berdasarkan spesifikasi teknisnya ke dalam kategori harga yang relevan. Tujuannya adalah untuk membantu pemangku kepentingan, termasuk produsen dan pengecer, memahami hubungan antara fitur teknis laptop dan harganya. Untuk menemukan strategi penetapan harga yang lebih efisien, memaksimalkan keuntungan, dan menarik customer dengan berbagai preferensi, klasifikasi ini dapat berguna.
#
# Kedua, tujuan penggalian data adalah untuk menemukan hubungan antara spesifikasi laptop dan tingkat kepuasan customer. Seseorang dapat memperoleh edukasi yang lebih baik tentang fitur atau kombinasi fitur yang paling berpengaruh terhadap kepuasan customer dengan melihat ulasan dan peringkat yang disediakan dalam dataset. Produsen dapat menggunakan informasi ini untuk meningkatkan desain produk mereka atau pengecer dapat menggunakannya untuk membuat strategi pemasaran yang lebih fokus.
#
# Ketiga, tujuan tambahan adalah membuat model regresi untuk memahami hubungan antara spesifikasi teknis dan harga laptop. Ini akan memberikan edukasi lebih lanjut tentang bagaimana variabel seperti tipe prosesor, kapasitas RAM, atau ukuran layar berkontribusi terhadap harga laptop. Ada kemungkinan bahwa analisis ini akan berfungsi sebagai dasar untuk kebijakan penetapan harga yang lebih cerdas dan beradaptasi dengan dinamika pasar.
#
# Keseluruhan, tujuan-tujuan ini memiliki potensi untuk memberikan wawasan yang komprehensif dan mendalam mengenai pasar laptop India, memungkinkan perusahaan untuk mengambil keputusan yang lebih terinformasi dan responsif terhadap perubahan dalam preferensi dan kebutuhan konsumen.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek ini mencakup sejumlah langkah yang terstruktur, dimulai dengan pengumpulan data tambahan untuk meningkatkan ketelitian analisis. Langkah selanjutnya mencakup pembersihan dan preprocessing data untuk memastikan bahwa informasi yang ada konsisten dan akurat. Pola dan hubungan dalam kumpulan data akan ditemukan dengan menggunakan algoritma penggalian data seperti klasifikasi, asosiasi, dan regresi. Setelah itu, hasil analisis akan dianalisis lebih lanjut untuk mendapatkan pemahaman yang lebih baik tentang pasar. Sangat penting untuk menyampaikan hasil penggalian data kepada pembuat keputusan dan pemangku kepentingan. Setelah itu, strategi bisnis yang didasarkan pada temuan ini akan diterapkan. Tujuan dari proses ini adalah untuk memberikan panduan yang dapat diukur dan tangguh untuk menjawab tantangan dan peluang yang ada di pasar laptop India.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Sumber dataset yang saya gunakan berasal dari platform Kaggle, yang merupakan salah satu sumber terkemuka untuk dataset. Kaggle menyediakan berbagai macam dataset dari berbagai bidang, mulai dari ilmu data dan analisis bisnis hingga kedokteran dan ilmu sosial.
#
# Link Dataset:
# https://www.kaggle.com/datasets/rajugc/laptop-selection-dataset

# %%
df = pd.read_csv('laptops.csv')
df.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
print("Baris: ", df.shape[0])
print("Kolom: ", df.shape[1])

#atau

df.shape
# Out:
# Baris:  984
# Kolom:  12
# (984, 12)

# %% [markdown]
# 1. **Penjelasan Command :**
# - df.shape : digunakan untuk mengetahui dimensi dari DataFrame, yaitu jumlah baris dan kolom dalam DataFrame.
#
# 2. **Informasi yang ditampilkan :**
# - (984, 12) : artinya ialah pada dataset ini memiliki 984 baris dan 12 column.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'img_link', 'name', 'price(in Rs.)', 'processor', 'ram',
#        'os', 'storage', 'display(in inch)', 'rating', 'no_of_ratings',
#        'no_of_reviews'],
#       dtype='object')

# %% [markdown]
# 1. Penjelasan Command :
# - df.columns : digunakan untuk mengakses atau mengambil nama-nama kolom dari DataFrame. Ini memberikan kumpulan nama-nama kolom dalam bentuk Index atau objek Seri.

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# img_link             object
# name                 object
# price(in Rs.)         int64
# processor            object
# ram                  object
# os                   object
# storage              object
# display(in inch)    float64
# rating              float64
# no_of_ratings       float64
# no_of_reviews       float64
# dtype: object

# %% [markdown]
# 1. **Penjelasan Command** :
# - df: Ini adalah nama DataFrame yang ingin Anda periksa tipe datanya.
# - dtypes: Ini adalah atribut dari DataFrame yang digunakan untuk mendapatkan tipe data dari setiap kolom dalam DataFrame.
#
# 2. **Penjelasan Output** :
# - Unnamed: 0: Kolom ini berisi nomor urut untuk setiap smartphone.
# - img_link: Kolom ini berisi tautan ke gambar smartphone.
# - name: Kolom ini berisi nama smartphone.
# - price(in Rs.): Kolom ini berisi harga smartphone dalam Rupee India.
# - processor: Kolom ini berisi jenis prosesor yang digunakan pada smartphone.
# - ram: Kolom ini berisi besaran RAM yang dimiliki smartphone.
# - OS: Kolom ini berisi sistem operasi yang digunakan pada smartphone.
# - storage: Kolom ini berisi besaran penyimpanan internal smartphone.
# - display(in inch): Kolom ini berisi ukuran layar smartphone dalam inci.
# - rating: Kolom ini berisi rating smartphone dari pengguna.
# - no_of_ratings: Kolom ini berisi jumlah orang yang memberikan rating pada smartphone.
# - no_of_reviews: Kolom ini berisi jumlah ulasan yang diberikan pengguna untuk smartphone.
#
# - int64: Tipe data integer 64-bit. Digunakan untuk kolom Unnamed: 0, price(in Rs.), dan no_of_ratings.
# - object: Tipe data objek. Digunakan untuk kolom img_link, name, processor, ram, OS, storage, dan display(in inch).
# - float64: Tipe data floating-point 64-bit. Digunakan untuk kolom rating dan no_of_reviews.

# %% [markdown]
# ####Informasi Lanjutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        984 non-null    int64
#  1   img_link          984 non-null    object
#  2   name              984 non-null    object
#  3   price(in Rs.)     984 non-null    int64
#  4   processor         984 non-null    object
#  5   ram               984 non-null    object
#  6   os                984 non-null    object
#  7   storage           984 non-null    object
#  8   display(in inch)  984 non-null    float64
#  9   rating            688 non-null    float64
#  10  no_of_ratings     688 non-null    float64
#  11  no_of_reviews     688 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 92.4+ KB

# %% [markdown]
# 1. `Unnamed: 0`: Kolom ini tampaknya merupakan indeks atau nomor baris. Terlihat tidak bernilai null dan memiliki tipe data integer (int64).
#
# 2. `img_link`: Ini adalah tautan (URL) ke gambar produk. Tidak seharusnya bernilai null, dan memiliki tipe data objek (object), yang mungkin mengindikasikan string.
#
# 3. `name`: Kolom ini berisi nama produk. Jumlah entri tidak-null seharusnya sama dengan jumlah total baris. Tipe datanya objek (object), mengindikasikan string.
#
# 4. `price(in Rs.)`: Harga produk dalam Rupee (Rs.). Tidak seharusnya bernilai null, dan memiliki tipe data integer (int64).
#
# 5. `processor`: Ini adalah spesifikasi prosesor komputer atau laptop. Tidak seharusnya bernilai null, dan memiliki tipe data objek (object), mengindikasikan string.
#
# 6. `ram`: Kapasitas RAM (Random Access Memory) dari produk. Tidak seharusnya bernilai null, dan memiliki tipe data objek (object), yang mungkin berisi string.
#
# 7. `os`: Sistem operasi yang digunakan oleh produk. Tidak seharusnya bernilai null, dan memiliki tipe data objek (object), mengindikasikan string.
#
# 8. `storage`: Kapasitas penyimpanan (hard drive atau SSD) dari produk. Tidak seharusnya bernilai null, dan memiliki tipe data objek (object), mengindikasikan string.
#
# 9. `display(in inch)`: Ukuran layar produk dalam inci. Tidak seharusnya bernilai null, dan memiliki tipe data float (float64).
#
# 10. `rating`: Rating produk. Mungkin bernilai null jika belum ada rating. Tipe data float (float64).
#
# 11. `no_of_ratings`: Jumlah penilaian yang diterima produk. Mungkin bernilai null jika tidak ada penilaian. Tipe data float (float64).
#
# 12. `no_of_reviews`: Jumlah ulasan yang diberikan produk. Mungkin bernilai null jika tidak ada ulasan. Tipe data float (float64).

# %%
df.describe()
# Out:
#        Unnamed: 0  price(in Rs.)  display(in inch)      rating  no_of_ratings  \
# count  984.000000     984.000000        984.000000  688.000000     688.000000
# mean   491.500000   80960.720528         15.148374    4.284884     718.091570
# std    284.200633   57421.220919          1.332078    0.330239    1750.817825
# min      0.000000   15990.000000         11.600000    1.600000       1.000000
# 25%    245.750000   42655.000000         14.000000    4.100000      14.000000
# 50%    491.500000   62990.000000         15.600000    4.300000      90.000000
# 75%    737.250000   94990.000000         15.600000    4.500000     453.000000
# max    983.000000  419990.000000         35.000000    5.000000   15492.000000
#
#        no_of_reviews
# count     688.000000
# mean       83.898256
# std       211.596726
# min         0.000000
# 25%         2.000000
# 50%        11.000000
# 75%        53.500000
# max      2054.000000

# %% [markdown]
# Unnamed: 0:
#
# Ini adalah kolom indeks atau nomor baris dalam data. Statistik yang diberikan meliputi jumlah total entri (count), rata-rata (mean), standar deviasi (std) yang mengukur sebaran data, nilai minimum (min) dan maksimum (max) dari indeks, serta kuartil pertama (25%), median (50%), dan kuartil ketiga (75%) yang membagi data menjadi empat bagian sama besar.
# price(in Rs.):
#
# Ini adalah harga produk dalam Rupee (Rs.). Statistik yang diberikan mencakup jumlah total entri, rata-rata harga produk, standar deviasi yang mengukur sebaran harga, harga minimum dan maksimum, serta kuartil pertama, median, dan kuartil ketiga dari harga produk.
# display(in inch):
#
# Ini adalah ukuran layar produk dalam inci. Statistik yang diberikan mencakup jumlah total entri, rata-rata ukuran layar, standar deviasi yang mengukur sebaran ukuran layar, ukuran layar minimum dan maksimum, serta kuartil pertama, median, dan kuartil ketiga dari ukuran layar.
# rating:
#
# Ini adalah rating produk. Statistik yang diberikan meliputi jumlah total entri, rata-rata rating produk, standar deviasi yang mengukur sebaran rating, rating minimum dan maksimum, serta kuartil pertama, median, dan kuartil ketiga dari rating produk.
# no_of_ratings:
#
# Ini adalah jumlah penilaian yang diterima produk. Statistik yang diberikan mencakup jumlah total entri, rata-rata jumlah penilaian, standar deviasi yang mengukur sebaran jumlah penilaian, jumlah penilaian minimum dan maksimum, serta kuartil pertama, median, dan kuartil ketiga dari jumlah penilaian.
# no_of_reviews:
#
# Ini adalah jumlah ulasan yang diberikan produk. Statistik yang diberikan mencakup jumlah total entri, rata-rata jumlah ulasan, standar deviasi yang mengukur sebaran jumlah ulasan, jumlah ulasan minimum dan maksimum, serta kuartil pertama, median, dan kuartil ketiga dari jumlah ulasan.

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0                                           img_link  \
# count   984.000000                                                984
# unique         NaN                                                584
# top            NaN  https://rukminim1.flixcart.com/image/312/312/x...
# freq           NaN                                                 41
# mean    491.500000                                                NaN
# std     284.200633                                                NaN
# min       0.000000                                                NaN
# 25%     245.750000                                                NaN
# 50%     491.500000                                                NaN
# 75%     737.250000                                                NaN
# max     983.000000                                                NaN
#
#                                  name  price(in Rs.)  \
# count                             984     984.000000
# ...

# %% [markdown]
# Dengan menggunakan `df.describe(include='all')`, kita dapat membuat penjelasan yang lebih lengkap untuk setiap kolom:
#
# 1. `Unnamed: 0`:
#    - Ini adalah kolom indeks atau nomor baris dalam data. Dalam deskripsi ini, tidak ada informasi yang disajikan untuk kolom ini, kecuali statistik deskriptif umum seperti jumlah, rata-rata, dan lainnya.
#
# 2. `img_link`:
#    - Ini adalah kolom yang berisi tautan (URL) ke gambar produk. Statistik yang diberikan termasuk jumlah entri yang unik (unique), tautan (URL) yang paling sering muncul (top), dan berapa kali tautan tersebut muncul (frequency).
#
# 3. `name`:
#    - Kolom ini berisi nama produk. Statistik yang diberikan meliputi jumlah entri unik, nama produk yang paling sering muncul, dan frekuensi kemunculan nama tersebut.
#
# 4. `price(in Rs.)`:
#    - Ini adalah kolom yang berisi harga produk dalam Rupee (Rs.). Statistik yang diberikan mencakup statistik deskriptif umum seperti rata-rata, standar deviasi, nilai minimum dan maksimum, serta kuartil.
#
# 5. `processor`:
#    - Kolom ini berisi spesifikasi prosesor komputer atau laptop. Statistik yang diberikan mencakup jumlah entri unik, spesifikasi prosesor yang paling sering muncul, dan frekuensi kemunculan spesifikasi tersebut.
#
# 6. `ram`:
#    - Kolom ini berisi kapasitas RAM (Random Access Memory) dari produk. Statistik yang diberikan mencakup jumlah entri unik, kapasitas RAM yang paling sering muncul, dan frekuensi kemunculan kapasitas tersebut.
#
# 7. `os`:
#    - Kolom ini berisi sistem operasi yang digunakan oleh produk. Statistik yang diberikan mencakup jumlah entri unik, sistem operasi yang paling sering muncul, dan frekuensi kemunculan sistem operasi tersebut.
#
# 8. `storage`:
#    - Kolom ini berisi kapasitas penyimpanan (hard drive atau SSD) dari produk. Statistik yang diberikan mencakup jumlah entri unik, kapasitas penyimpanan yang paling sering muncul, dan frekuensi kemunculan kapasitas tersebut.
#
# 9. `display(in inch)`:
#    - Ini adalah kolom yang berisi ukuran layar produk dalam inci. Statistik yang diberikan mencakup statistik deskriptif umum seperti rata-rata, standar deviasi, nilai minimum dan maksimum, serta kuartil.
#
# 10. `rating`:
#     - Ini adalah kolom yang berisi rating produk. Statistik yang diberikan mencakup statistik deskriptif umum seperti rata-rata, standar deviasi, nilai minimum dan maksimum, serta kuartil. Namun, hanya 688 dari total 984 entri yang tidak-null.
#
# 11. `no_of_ratings`:
#     - Kolom ini berisi jumlah penilaian yang diterima produk. Statistik yang diberikan mencakup statistik deskriptif umum seperti rata-rata, standar deviasi, nilai minimum dan maksimum, serta kuartil. Hanya 688 dari total 984 entri yang tidak-null.
#
# 12. `no_of_reviews`:
#     - Kolom ini berisi jumlah ulasan yang diberikan produk. Statistik yang diberikan mencakup statistik deskriptif umum seperti rata-rata, standar deviasi, nilai minimum dan maksimum, serta kuartil. Hanya 688 dari total 984 entri yang tidak-null.
#
# Dengan menggunakan `df.describe(include='all')`, kita mendapatkan deskripsi yang lebih komprehensif untuk setiap kolom, termasuk informasi tentang entri unik, nilai yang paling sering muncul, dan frekuensi kemunculan nilai-nilai tersebut.

# %%
df.corr(numeric_only = True)
# Out:
#                   Unnamed: 0  price(in Rs.)  display(in inch)    rating  \
# Unnamed: 0          1.000000       0.029016          0.007415 -0.177889
# price(in Rs.)       0.029016       1.000000          0.088121  0.290309
# display(in inch)    0.007415       0.088121          1.000000  0.027342
# rating             -0.177889       0.290309          0.027342  1.000000
# no_of_ratings      -0.125187      -0.128684         -0.084907  0.054964
# no_of_reviews      -0.113257      -0.124797         -0.086153  0.044456
#
#                   no_of_ratings  no_of_reviews
# Unnamed: 0            -0.125187      -0.113257
# price(in Rs.)         -0.128684      -0.124797
# display(in inch)      -0.084907      -0.086153
# rating                 0.054964       0.044456
# no_of_ratings          1.000000       0.977843
# no_of_reviews          0.977843       1.000000

# %% [markdown]
# 1. **Penjelasan COmmand** :
# - Syntax df.corr(numeric_only=True) digunakan untuk menghitung korelasi antar kolom dalam DataFrame df hanya untuk kolom-kolom numerik.
# - df: Ini adalah nama DataFrame yang digunakan, yang berisi data yang ingin dihitung korelasinya.
# - corr(): Ini adalah metode Pandas yang digunakan untuk menghitung korelasi antar kolom dalam DataFrame.
# - numeric_only=True: Ini adalah parameter opsional dalam metode corr().
#
# *Gambar tersebut menunjukkan tabel korelasi untuk 6 variabel:
# - Unnamed: Kolom ini tampaknya berisi ID unik untuk setiap baris.
# - price(in Rs.): Harga produk dalam Rupee.
# - display(in inch): Ukuran layar produk dalam inci.
# - rating: Penilaian rata-rata produk.
# - no_of_ratings: Jumlah orang yang memberi peringkat pada produk.
# - no_of_reviews: Jumlah ulasan yang ditulis untuk produk.

# %%
px.imshow(df.corr(numeric_only = True))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. **Penjelasan Command** :
# - Syntax px.imshow(df.corr(numeric_only=True)) digunakan untuk membuat plot heatmap (peta panas) dari korelasi antar kolom numerik dalam DataFrame df menggunakan Plotly Express (px).
# - df.corr(numeric_only=True): Ini adalah metode Pandas yang digunakan untuk menghitung korelasi antar kolom dalam DataFrame.
# - px.imshow(...): Ini adalah fungsi dari Plotly Express (px) yang digunakan untuk membuat plot heatmap (peta panas).
#
# 2. **Penjelasan Output** :
# - Kuning: Korelasi positif yang kuat
# - Merah: Korelasi negatif yang kuat
# - Biru: Korelasi yang lemah atau tidak ada

# %% [markdown]
# ##**Exploratory Data Analysis**

# %%
df = pd.read_csv('laptops.csv')
price_counts = df['price(in Rs.)'].value_counts()
max_value = price_counts.max()

plt.figure(figsize=(8, 6))
sorted_data = df['price(in Rs.)'].sort_values().reset_index(drop=True)
plt.hist(sorted_data, bins=5, color='skyblue', edgecolor='black')

plt.title('Histogram Harga Produk')
plt.xlabel('Harga (Rupee)')
plt.ylabel('Frekuensi')

plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 1. **Penjelasan Command** :
# - df = pd.read_csv('laptops.csv'): Ini adalah fungsi Pandas yang digunakan untuk membaca file CSV dan memuatnya ke dalam DataFrame df. File CSV yang dibaca dalam hal ini adalah 'laptops.csv'.
# - price_counts = df['price(in Rs.)'].value_counts(): Ini adalah operasi yang menghitung jumlah kemunculan setiap nilai harga dalam kolom 'price(in Rs.)' dari DataFrame df, menggunakan metode value_counts(). Hasilnya disimpan dalam variabel price_counts.
# - max_value = price_counts.max(): Ini adalah operasi yang digunakan untuk menemukan nilai maksimum dalam variabel price_counts, yang merupakan jumlah kemunculan nilai harga tertinggi.
# - plt.figure(figsize=(8, 6)): Ini adalah fungsi yang digunakan untuk membuat figur (gambar) baru dengan ukuran 8x6 inch menggunakan Matplotlib (plt).
# - sorted_data = df['price(in Rs.)'].sort_values().reset_index(drop=True): Ini adalah operasi yang digunakan untuk mengurutkan nilai harga dalam kolom 'price(in Rs.)' dari DataFrame df secara ascending, kemudian disimpan dalam variabel sorted_data. Metode reset_index(drop=True) digunakan untuk mereset indeks DataFrame setelah diurutkan.
# - plt.hist(sorted_data, bins=5, color='skyblue', edgecolor='black'): Ini adalah fungsi yang digunakan untuk membuat histogram dari data harga yang telah diurutkan (sorted_data). Parameter bins=5 menentukan jumlah bin yang digunakan dalam histogram. Parameter color='skyblue' menentukan warna isi histogram, dan edgecolor='black' menentukan warna garis tepi histogram.
# - plt.title('Histogram Harga Produk'): Ini adalah fungsi yang digunakan untuk menambahkan judul pada plot menggunakan Matplotlib (plt). Judul yang ditambahkan adalah 'Histogram Harga Produk'.
# - plt.xlabel('Harga (Rupee)'): Ini adalah fungsi yang digunakan untuk menambahkan label pada sumbu x pada plot menggunakan Matplotlib (plt). Label yang ditambahkan adalah 'Harga (Rupee)'.
# - plt.ylabel('Frekuensi'): Ini adalah fungsi yang digunakan untuk menambahkan label pada sumbu y pada plot menggunakan Matplotlib (plt). Label yang ditambahkan adalah 'Frekuensi'.
# - plt.legend(): Ini adalah fungsi yang digunakan untuk menampilkan legenda pada plot menggunakan Matplotlib (plt). Namun, dalam syntax ini, tidak ada elemen yang diberi label, sehingga legenda tidak ditampilkan.
# - plt.grid(True, linestyle='--', alpha=0.7): Ini adalah fungsi yang digunakan untuk menambahkan grid pada plot menggunakan Matplotlib (plt). Parameter linestyle='--' digunakan untuk mengatur gaya garis grid menjadi putus-putus, dan alpha=0.7 digunakan untuk mengatur transparansi grid.
# - plt.tight_layout(): Ini adalah fungsi yang digunakan untuk menyesuaikan layout plot agar terlihat lebih rapi.
# - plt.show(): Ini adalah fungsi yang digunakan untuk menampilkan plot menggunakan Matplotlib (plt).
#
# 2. **Penjelasan Output** :
# - Sebagian besar produk memiliki harga antara 50.000 Rs dan 150.000 Rs.
# - Ada beberapa produk yang harganya lebih rendah dari 50.000 Rs dan beberapa produk yang harganya lebih tinggi dari 150.000 Rs, namun jumlahnya tidak sebanyak produk yang berada di kisaran 50.000 Rs - 150.000 Rs.

# %%
sns.scatterplot(x='Unnamed: 0', y='price(in Rs.)', data=df)
plt.title('Korelasi antara Unnamed dan price(in Rs.)')
plt.xlabel('Unnamed: 0')
plt.ylabel('price(in Rs.)')
# Out:
# Text(0, 0.5, 'price(in Rs.)')

# %% [markdown]
# 1. **Penjelasan Command**: sns.scatterplot(x='Unnamed: 0', y='price(in Rs.)', data=df): Ini adalah pemanggilan fungsi scatterplot() dari Seaborn. Fungsi ini digunakan untuk membuat scatter plot.
#
# Parameter yang digunakan adalah:
# - x='Unnamed: 0': Ini menentukan kolom yang akan digunakan sebagai sumbu x pada scatter plot.
# - y='price(in Rs.)': Ini menentukan kolom yang akan digunakan sebagai sumbu y pada scatter plot. Dalam hal ini, kolom 'price(in Rs.)' dipilih untuk sumbu y.
# - data=df: Ini menentukan DataFrame yang akan digunakan untuk mengambil data untuk plot. Dalam hal ini, DataFrame yang digunakan adalah df.
# - plt.title('Korelasi antara Unnamed dan price(in Rs.)'): Ini adalah fungsi yang digunakan untuk menambahkan judul pada plot menggunakan Matplotlib (plt).
# - plt.xlabel('Unnamed: 0'): Ini adalah fungsi yang digunakan untuk menambahkan label pada sumbu x pada plot menggunakan Matplotlib. Parameter yang digunakan adalah string 'Unnamed: 0', yang akan menjadi label sumbu x.
# - plt.ylabel('price(in Rs.)'): Ini adalah fungsi yang digunakan untuk menambahkan label pada sumbu y pada plot menggunakan Matplotlib. Parameter yang digunakan adalah string 'price(in Rs.)', yang akan menjadi label sumbu y.
#
# 2. **Penjelasan Output** :
# - Terdapat rentang harga yang luas pada sumbu y, dari 0 hingga 400.000 rupee.
# - Ada lebih banyak titik data pada harga yang lebih rendah dibandingkan dengan harga yang lebih tinggi.
# - Ada beberapa outlier, yaitu titik data yang berada jauh dari kelompok titik utama.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
pd.DataFrame(df.isna().sum() /len(df) *100, columns=['Null Ratio%'])
# Out:
#                   Null Ratio%
# Unnamed: 0           0.000000
# img_link             0.000000
# name                 0.000000
# price(in Rs.)        0.000000
# processor            0.000000
# ram                  0.000000
# os                   0.000000
# storage              0.000000
# display(in inch)     0.000000
# rating              30.081301
# no_of_ratings       30.081301
# no_of_reviews       30.081301

# %% [markdown]
# 1. **Penjelasan Command** :
# - df.isna(): Ini adalah fungsi Pandas yang digunakan untuk menghasilkan DataFrame boolean dengan nilai True di lokasi di mana terdapat nilai null (missing value) dan False di lokasi di mana nilai tidak null.
# - .sum(): Ini adalah metode Pandas yang digunakan untuk menjumlahkan nilai True (yang diinterpretasikan sebagai 1) dalam setiap kolom DataFrame. Hasilnya adalah jumlah nilai null (missing value) dalam setiap kolom.
# - / len(df) * 100: Ini adalah operasi matematika yang digunakan untuk menghitung rasio persentase nilai null (missing value) terhadap jumlah total baris dalam DataFrame df.
# - pd.DataFrame(...): Ini adalah pembuatan DataFrame baru dengan menggunakan fungsi pd.DataFrame(). Parameter pertamanya adalah hasil operasi perhitungan sebelumnya (df.isna().sum() / len(df) * 100), yang merupakan Series yang berisi rasio persentase nilai null (missing value) di setiap kolom. Parameter keduanya adalah columns=['Null Ratio%'], yang menentukan nama kolom untuk DataFrame baru yang dibuat.
#
# 2. **Penjelasan Output** :
# - Unnamed: 0: Indeks baris.
# - img_link: Tautan ke gambar produk.
# - name: Nama produk.
# - price(in Rs.): Harga produk dalam rupee.
# - processor: Prosesor yang digunakan dalam produk.
# - ram: Jumlah RAM dalam produk.
# - OS: Sistem operasi yang digunakan dalam produk.
# - storage: Kapasitas penyimpanan produk.
# - display(in inch): Ukuran layar produk dalam inci.
# - rating: Penilaian produk.
# - no_of_ratings: Jumlah penilaian produk.
# - no_of_reviews: Jumlah ulasan produk.

# %% [markdown]
# ####Outliers Values

# %%
fig = px.scatter(df, x='display(in inch)', y='price(in Rs.)', color='rating', title='',
                 labels={'display(in inch)': 'Display', 'price(in Rs.)': 'Price', 'rating': 'Rating'})
fig.update_layout(xaxis_title='Top Laptops (From Flipkart)', yaxis_title='Rating')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. **Penjelasan Command** :
# - fig = px.scatter(df, x='display(in inch)', y='price(in Rs.)', color='rating', title='', labels={'display(in inch)': 'Display', 'price(in Rs.)': 'Price', 'rating': 'Rating'}): Ini adalah pemanggilan fungsi px.scatter() dari Plotly Express (px). Parameter yang digunakan adalah:
# - df: DataFrame yang akan digunakan untuk membuat scatter plot.
# x='display(in inch)': Nama kolom yang akan digunakan sebagai sumbu x pada scatter plot. Dalam hal ini, digunakan kolom 'display(in inch)'.
# - y='price(in Rs.)': Nama kolom yang akan digunakan sebagai sumbu y pada scatter plot. Dalam hal ini, digunakan kolom 'price(in Rs.)'.
# - color='rating': Nama kolom yang akan digunakan untuk memberi warna pada titik-titik scatter plot. Dalam hal ini, digunakan kolom 'rating'.
# title='': Judul dari plot. Dalam hal ini, judul tidak diisi sehingga akan muncul tanpa judul.
# - labels={'display(in inch)': 'Display', 'price(in Rs.)': 'Price', 'rating': 'Rating'}: Penamaan label sumbu dan warna yang digunakan pada plot. Parameter ini digunakan untuk memberi label yang lebih deskriptif pada sumbu-sumbu dan warna pada plot.
#
# 2. **Penjelasan Output** :
# Grafik ini menunjukkan hubungan antara ukuran tampilan laptop, harga, dan rating.
# Semakin besar ukuran tampilan, semakin tinggi harga laptop.
# Rating laptop tidak menunjukkan korelasi yang jelas dengan ukuran tampilan atau harga.
# Laptop dengan rating tinggi dapat ditemukan di berbagai ukuran tampilan dan rentang harga.
# Ada beberapa laptop dengan ukuran tampilan besar yang memiliki harga relatif rendah.
# Ada beberapa laptop dengan ukuran tampilan kecil yang memiliki harga relatif tinggi.

# %% [markdown]
# ####Duplicated Values

# %%
df = pd.read_csv('laptops.csv')

duplicate_rows = df[df.duplicated()]

print("Jumlah nilai yang diduplikasi dalam dataset:", len(duplicate_rows))
# Out:
# Jumlah nilai yang diduplikasi dalam dataset: 0

# %% [markdown]
# Pada hasil "Jumlah nilai yang diduplikasi dalam dataset: 0" menunjukkan bahwa tidak ada nilai yang diduplikasi dalam dataset. Ini berarti setiap baris dalam dataset memiliki nilai yang unik, dan tidak ada baris yang sama persis dengan baris lainnya.
#
# Ketika tidak ada nilai yang diduplikasi dalam dataset maka:
# - Data memiliki keunikan di setiap barisnya.
# - Tidak perlu dilakukan tindakan lebih lanjut terkait penghapusan atau pengelolaan nilai duplikat.
# - Data ini mungkin telah melalui proses penghapusan nilai duplikat sebelumnya atau telah diambil dari sumber yang telah membersihkan data duplikat.

# %% [markdown]
# ####Inconsistent Values / Noise (Optional)

# %% [markdown]
# Pada Dataset saya tidak terdapat noise.

# %% [markdown]
# ## **Inisiasi Variabel untuk menyimpan dataframe**

# %%
df = pd.read_csv('laptops.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# ...

# %% [markdown]
# ### penjelasan

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# # **DATA CLEANING**

# %% [markdown]
# Data Cleaning merupakan proses menghapus atau memodifikasi data yang dianggap tidak lengkap, duplikat, tidak akurat, salah format, maupun rusak dalam kumpulan data yang dimiliki.

# %% [markdown]
# ##**Penanganan Missing Values**

# %% [markdown]
# #### **Pengecekan Missing Values**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0           0.000000
# img_link             0.000000
# name                 0.000000
# price(in Rs.)        0.000000
# processor            0.000000
# ram                  0.000000
# os                   0.000000
# storage              0.000000
# display(in inch)     0.000000
# rating              30.081301
# no_of_ratings       30.081301
# no_of_reviews       30.081301
# dtype: float64

# %% [markdown]
# **Penjelasan Output :**
# pada gambar diatas, terdapat 3 kolom (Kolom rating, no_of_ratings dan no_of_reviews) dengan bentuk data kosong yang dimana presentase dibawah 70% sehingga harus dilakukan imputasi.

# %% [markdown]
#  **Nilai kosong pada kolom 'rating' dibawah ini :**

# %%
df[df['rating'].isnull()]
# Out:
#      Unnamed: 0                                           img_link  \
# 7             7  https://rukminim1.flixcart.com/image/312/312/x...
# 53           53  https://rukminim1.flixcart.com/image/312/312/x...
# 58           58  https://rukminim1.flixcart.com/image/312/312/x...
# 64           64  https://rukminim1.flixcart.com/image/312/312/x...
# 72           72  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 971         971  https://rukminim1.flixcart.com/image/312/312/x...
# 972         972  https://rukminim1.flixcart.com/image/312/312/x...
# 975         975  https://rukminim1.flixcart.com/image/312/312/x...
# 977         977  https://rukminim1.flixcart.com/image/312/312/x...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                                   name  price(in Rs.)  \
# 7                  DELL Vostro Ryzen 3 Quad Core 5425U          36890
# ...

# %% [markdown]
# Pada kolom 'rating' diatas valuesnya ialah Nan yang merupakan data kosong.

# %% [markdown]
# **Nilai kosong pada kolom 'no_of_ratings' dibawah ini :**

# %%
df[df['no_of_ratings'].isnull()]
# Out:
#      Unnamed: 0                                           img_link  \
# 7             7  https://rukminim1.flixcart.com/image/312/312/x...
# 53           53  https://rukminim1.flixcart.com/image/312/312/x...
# 58           58  https://rukminim1.flixcart.com/image/312/312/x...
# 64           64  https://rukminim1.flixcart.com/image/312/312/x...
# 72           72  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 971         971  https://rukminim1.flixcart.com/image/312/312/x...
# 972         972  https://rukminim1.flixcart.com/image/312/312/x...
# 975         975  https://rukminim1.flixcart.com/image/312/312/x...
# 977         977  https://rukminim1.flixcart.com/image/312/312/x...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                                   name  price(in Rs.)  \
# 7                  DELL Vostro Ryzen 3 Quad Core 5425U          36890
# ...

# %% [markdown]
#  Pada kolom 'no_of_ratings' diatas valuesnya ialah Nan yang merupakan data kosong

# %% [markdown]
# **Nilai kosong pada kolom 'no_of_reviews' dibawah ini :**

# %%
df[df['no_of_reviews'].isnull()]
# Out:
#      Unnamed: 0                                           img_link  \
# 7             7  https://rukminim1.flixcart.com/image/312/312/x...
# 53           53  https://rukminim1.flixcart.com/image/312/312/x...
# 58           58  https://rukminim1.flixcart.com/image/312/312/x...
# 64           64  https://rukminim1.flixcart.com/image/312/312/x...
# 72           72  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 971         971  https://rukminim1.flixcart.com/image/312/312/x...
# 972         972  https://rukminim1.flixcart.com/image/312/312/x...
# 975         975  https://rukminim1.flixcart.com/image/312/312/x...
# 977         977  https://rukminim1.flixcart.com/image/312/312/x...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                                   name  price(in Rs.)  \
# 7                  DELL Vostro Ryzen 3 Quad Core 5425U          36890
# ...

# %% [markdown]
# Pada kolom 'no_of_reviews' diatas valuesnya ialah Nan yang merupakan data kosong

# %% [markdown]
# ### **Hapus Missing Values**

# %% [markdown]
# Pada Dataset saya tidak ada yang dihapus, dikarenanakan presentase dibawah 70%.

# %% [markdown]
# #### **Imputasi Missing Values**

# %% [markdown]
# Imputasi data adalah proses mengisi atau mengganti nilai-nilai yang hilang dalam sebuah dataset dengan nilai yang disyaratkan atau yang dianggap sesuai.
#
# Untuk kolom 'rating', saya melakukan **Imputasi Values** karena presentase missing values nya kurang dari 70%.

# %%
df['rating'].dropna().describe()
# Out:
# count    688.000000
# mean       4.284884
# std        0.330239
# min        1.600000
# 25%        4.100000
# 50%        4.300000
# 75%        4.500000
# max        5.000000
# Name: rating, dtype: float64

# %% [markdown]
# Pada hasil analisis statistik data terlihat cukup terdistribusi dengan baik, sehingga imputasi values menggunakan mean dari kolom 'rating'.

# %%
df['rating'] = df['rating'].fillna(df['rating'].dropna().mean())

# %% [markdown]
# Syntax di atas digunakan untuk mengisi nilai-nilai yang hilang dalam kolom 'rating' dengan mean dari nilai yang ada dalam kolom tersebut.

# %% [markdown]
# Untuk kolom 'no_of_ratings', saya melakukan Imputasi Values karena presentase missing values nya kurang dari 70%.

# %%
df['no_of_ratings'].dropna().describe()
# Out:
# count      688.000000
# mean       718.091570
# std       1750.817825
# min          1.000000
# 25%         14.000000
# 50%         90.000000
# 75%        453.000000
# max      15492.000000
# Name: no_of_ratings, dtype: float64

# %% [markdown]
# Pada hasil analisis statistik data terlihat cukup terdistribusi dengan baik, sehingga imputasi values menggunakan mean dari kolom 'no_of_ratings'.

# %%
df['no_of_ratings'] = df['no_of_ratings'].fillna(df['no_of_ratings'].dropna().mean())

# %% [markdown]
# Syntax di atas digunakan untuk mengisi nilai-nilai yang hilang dalam kolom 'no_of_ratings' dengan rata-rata dari nilai yang ada dalam kolom tersebut.

# %% [markdown]
# Untuk kolom 'no_of_reviews', saya melakukan Imputasi Values karena presentase missing values nya kurang dari 70%.

# %%
df['no_of_reviews'].dropna().describe()
# Out:
# count     688.000000
# mean       83.898256
# std       211.596726
# min         0.000000
# 25%         2.000000
# 50%        11.000000
# 75%        53.500000
# max      2054.000000
# Name: no_of_reviews, dtype: float64

# %% [markdown]
# Pada hasil analisis statistik data terlihat cukup terdistribusi dengan baik, sehingga imputasi values menggunakan mean dari kolom 'no_of_reviews'.

# %%
df['no_of_reviews'] = df['no_of_reviews'].fillna(df['no_of_reviews'].dropna().mean())

# %% [markdown]
# Syntax di atas digunakan untuk mengisi nilai-nilai yang hilang dalam kolom 'no_of_reviews' dengan rata-rata dari nilai yang ada dalam kolom tersebut.

# %% [markdown]
# ### **Pengecekan Ulang**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                   Null Ratio %
# Unnamed: 0                 0.0
# img_link                   0.0
# name                       0.0
# price(in Rs.)              0.0
# processor                  0.0
# ram                        0.0
# os                         0.0
# storage                    0.0
# display(in inch)           0.0
# rating                     0.0
# no_of_ratings              0.0
# no_of_reviews              0.0

# %% [markdown]
# Pengecekan ulang diatas berfungsi untuk memperlihatkan kolom data setelah diimputasi, dimana sudah tidak ada data dalam bentuk data kosong.

# %% [markdown]
# ## **Penanganan Duplikat**

# %% [markdown]
# ### **Pengecekan Duplikat**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, img_link, name, price(in Rs.), processor, ram, os, storage, display(in inch), rating, no_of_ratings, no_of_reviews]
# Index: []

# %% [markdown]
# Pada gambar diatas tidak ada tertampil data yang terduplikat.

# %% [markdown]
# ### **Hapus Nilai Duplikat**

# %% [markdown]
# Pada dataset ini tidak terdapat duplikasi, sehingga tidak perlu menghapus nilai duplikat.

# %% [markdown]
# ## **Penanganan Ouliers**

# %% [markdown]
# ### **Pengecekan Ouliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Unnamed: 0                   0.000000
# price(in Rs.)                8.028455
# display(in inch)             1.219512
# rating                      10.670732
# no_of_ratings                7.418699
# no_of_reviews                7.520325

# %% [markdown]
# Persentase outliers dalam setiap kolom menunjukkan proporsi data yang signifikan yang secara ekstrim berbeda dari sebagian besar data lainnya dalam dataset. Ini dapat mengindikasikan adanya nilai-nilai yang tidak biasa atau ekstrem dalam atribut-atribut tersebut, seperti harga yang sangat tinggi atau sangat rendah, ukuran layar yang tidak biasa, atau nilai rating yang ekstrem.

# %%
boxplot = df.drop('Unnamed: 0', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# ### **Hapus Outliers**

# %% [markdown]
# Outliers pada variabel harga (price) digunakan untuk mengevaluasi karakteristik dari dataset komputer tersebut. Oleh karena itu, penghapusan outliers dapat mengubah karakteristik dataset komputer tersebut.

# %% [markdown]
# ### **Imputasi Outliers**

# %% [markdown]
# Karena tidak ada penghapusan Outliers, maka tidak ada data yang diimputasi.

# %% [markdown]
# ### **Pengecekan Ulang**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom             Persentase Outliers
# Unnamed: 0                   0.000000
# price(in Rs.)                8.028455
# display(in inch)             1.219512
# rating                      10.670732
# no_of_ratings                7.418699
# no_of_reviews                7.520325

# %%
boxplot = df.drop('Unnamed: 0', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# Pada pengecekan ulang ini, tidak ada perbedaan dikarenakan tidak ada data nilai yang dihapus dan di imputasi.

# %% [markdown]
# ## **Construct Data**

# %% [markdown]
# ### **Melakukan Rekayasa Fitur (Feature Engineering)**

# %%
def categorize_price(price):
    if price < 30000:
        return 'Cheap'
    elif 30000 <= price < 45000:
        return 'Affordable'
    else:
        return 'Expensive'

df['PriceCategory'] = df['price(in Rs.)'].apply(categorize_price)

# %% [markdown]
# Pada syntax diatas menciptakan kolom baru yang bernama PriceCategory yang dimana fungsinya untuk mengelompokkan harga kedalam 3 kategori saja yaitu Cheap, Affordable, dan Expensive.

# %% [markdown]
# ### **Pengecekan Hasil**

# %%
df.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# ...

# %% [markdown]
# Output diatas untuk melihatkan perubahan dari yang sebeleumnya tidak ada kolom PriceCategory.

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# ### **Mengurangi Fitur Yang Kurang Relevan**

# %% [markdown]
# Pada dataset saya, seluruh kolom berkorelasi erat, sesuai dengan Goals Business yang dimana untuk meng-informasikan data laptop dengan rinci agar para customer tau membeli laptop sesuai kebutuhan.

# %% [markdown]
# ### **Pengecekan Hasil**

# %%
df.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# ...

# %% [markdown]
# ### **Hasil Data Cleaning**

# %%
df_cleaned = df.dropna()

print('\nData setelah cleaning:')
print(df_cleaned.head())
# Out:
# Data setelah cleaning:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# ...

# %% [markdown]
# ### **Membuat Hasil CSV**

# %%
df_cleaned.to_csv('Data Cleaning.csv', index= False)

# %% [markdown]
# ## **Data Transformation**

# %%
df.describe()
# Out:
#        Unnamed: 0  price(in Rs.)  display(in inch)      rating  no_of_ratings  \
# count  984.000000     984.000000        984.000000  984.000000      984.00000
# mean   491.500000   80960.720528         15.148374    4.284884      718.09157
# std    284.200633   57421.220919          1.332078    0.276077     1463.66797
# min      0.000000   15990.000000         11.600000    1.600000        1.00000
# 25%    245.750000   42655.000000         14.000000    4.200000       37.00000
# 50%    491.500000   62990.000000         15.600000    4.284884      385.00000
# 75%    737.250000   94990.000000         15.600000    4.400000      718.09157
# max    983.000000  419990.000000         35.000000    5.000000    15492.00000
#
#        no_of_reviews
# count     984.000000
# mean       83.898256
# std       176.892962
# min         0.000000
# 25%         3.000000
# 50%        39.500000
# 75%        83.898256
# max      2054.000000

# %% [markdown]
# ### **Mapping**

# %%
df.to_csv('data-before-mapping.csv', index=False)

# %%
df['PriceCategory'] = df['PriceCategory'].map({'Cheap': 0, 'Affordable': 1,'Expensive': 2}).astype(int)

# %% [markdown]
# Querry di atas berfungsi untuk membuat kolom baru yang disebut 'PriceCategory' dalam DataFrame 'df'. Kolom baru ini akan berisi nilai kategoris yang mewakili kategori harga dari laptop berdasarkan kriteria yang sudah ditentukan sebelumnya yaitu 0 untuk 'Cheap', 1 untuk 'Affordable', dan 2 untuk 'Expensive'.
#
# Berikut adalah penjelasannya:
#
# df['PriceCategory'] =: Ini adalah langkah pertama dalam querry yang menunjukkan bahwa kita membuat kolom baru yang disebut 'YearCategory' dalam DataFrame 'df' dan mengisinya dengan nilai kategoris.
#
# df['PriceCategory'].map({'Cheap': 0, 'Afforddable': 1,'Expensive': 2}): Di sini, kita menggunakan metode map() untuk memetakan nilai-nilai dalam kolom 'PriceCategory' ke nilai-nilai baru sesuai dengan peta yang diberikan. Peta ini adalah sebuah dictionary yang menetapkan setiap kategori ('Cheap', 'Affordable', 'Expensive') ke nilai angka yang sesuai (0, 1, 2).
#
# .astype(int): Terakhir, kita mengonversi tipe data kolom 'PriceCategory' menjadi tipe data integer dengan menggunakan metode astype(int). Ini diperlukan karena setelah pemetaan, nilai-nilai tersebut mungkin menjadi float, dan kita ingin mengubahnya menjadi integer.

# %% [markdown]
# ## **Encoding**

# %%
df.drop(columns = ['Unnamed: 0','img_link','name']).to_csv('buat komposisi.csv', index=False)

# %%
# df = pd.get_dummies(df)

# %% [markdown]
# 'pd.get_dummies(df)' digunakan untuk melakukan one-hot encoding pada DataFrame df, yang berarti mengubah variabel kategorikal menjadi representasi numerik biner yang dapat digunakan dalam analisis atau pemodelan data.

# %% [markdown]
# ### **Pengecekan Hasil**

# %%
df.drop(columns = ['Unnamed: 0','img_link','name','PriceCategory']).to_csv('buat predict.csv', index=False)

# %%
mapping_data = {}
index = 0
for i in df['os'].unique():
  mapping_data[i] = index
  index += 1

df['os'] = df['os'].map(mapping_data).astype(int)

# %%
mapping_data = {}
index = 0
for i in df['storage'].unique():
  mapping_data[i] = index
  index += 1

df['storage'] = df['storage'].map(mapping_data).astype(int)

# %%
mapping_data = {}
index = 0
for i in df['ram'].unique():
  mapping_data[i] = index
  index += 1

df['ram'] = df['ram'].map(mapping_data).astype(int)

# %%
mapping_data = {}
index = 0
for i in df['processor'].unique():
  mapping_data[i] = index
  index += 1

df['processor'] = df['processor'].map(mapping_data).astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  processor  ram  \
# 0             Lenovo Intel Core i5 11th Gen          62990          0    0
# 1            Lenovo V15 G2 Core i3 11th Gen          37500          1    1
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990          2    1
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990          3    1
# 4                   Lenovo Athlon Dual Core          18990          4    2
#
#    os  storage  display(in inch)  rating  no_of_ratings  no_of_reviews  \
# ...

# %% [markdown]
# # **Hasil Data Cleaning**

# %%
# df_cleaned = df.dropna()

# print('\nData setelah cleaning:')
# print(df_cleaned.head())

# %% [markdown]
# ### **Membuat File CSV**

# %%
# df_cleaned.to_csv('Data Cleaning.csv', index= False)

# %% [markdown]
# # **Modelling**

# %% [markdown]
# #### **Library untuk Splitting Data**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### **Library untuk Normalisasi Data**

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### **Library Untuk Build Model**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## **Select Modelling Techniques**

# %% [markdown]
# Saya memilih pendekatan modelling predict karena terkait erat dengan tujuan bisnis saya, yang mencakup penggalian data yang mendalam untuk memberikan pemahaman holistik tentang pasar laptop di India. Hal ini melibatkan analisis menyeluruh terhadap aspek teknis, ulasan pelanggan yang terkumpul, serta faktor harga yang relevan.

# %% [markdown]
# ## **Modelling Predict**

# %% [markdown]
# ### **Pre-Processing**

# %% [markdown]
# ##### **Split Data**

# %%
x = df.drop(['PriceCategory','name','img_link','Unnamed: 0'], axis=1)
y = df['PriceCategory']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Split Data berfungsi untuk memisahkan dataset menjadi training data dan testing data yang dimana kolom 'PriceCategory' menjadi kolom target yang akan diprediksi

# %%
x_train
# Out:
#      price(in Rs.)  processor  ram  os  storage  display(in inch)  rating  \
# 398          39990          1    1   1        0              15.6     4.1
# 523          56049          9    1   1        0              15.6     4.2
# 809          74490         39   19   4        0              13.3     4.2
# 501          39490          1    1   1        2              15.6     4.0
# 430         157990         13    4   1        3              15.6     4.0
# ..             ...        ...  ...  ..      ...               ...     ...
# 106          89990         13    0   1        0              15.6     4.5
# 270         243990         25   14   3        3              16.2     4.8
# 860          66490         11    1   4        0              14.0     4.4
# 435          62990          0    0   0        0              15.6     4.5
# 102         113490         18    7   3        2              13.6     4.8
#
#      no_of_ratings  no_of_reviews
# 398           48.0            2.0
# ...

# %% [markdown]
# x_train merupakan fitur dari data pelatihan yang telah dipisahkan. Ini digunakan untuk melatih model. x_train berisi nilai dari fitur-fitur yang digunakan sebagai input untuk melatih model.

# %% [markdown]
# ##### **Normalisasi Data**

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train)

x_test_norm = scaler.transform(x_test)

# %% [markdown]
# Syntax diatas berfungsi untuk menormalkan atau menyesuaikan fitur-fitur dalam data pelatihan (x_train) dan data pengujian (x_test). Proses normalisasi ini berguna untuk mengubah rentang nilai dari setiap fitur sehingga rentang nilainya menjadi antara 0 dan 1.

# %% [markdown]
# ### **Build and Train Model**

# %% [markdown]
# ##### **Gaussian Naive Bayes**

# %% [markdown]
# Gaussian Naive Bayes merupakan salah satu algoritma pemecahan masalah yang termasuk kedalam metode klasifikasi (model preditif) pada Data Mining.

# %%
gnb = GaussianNB()

gnb.fit(x_train_norm, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# syntax di atas berfungsi untuk menginisialisasi dan melatih model menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label data pelatihan (y_train).
# Untuk outputnya diatas menunjukkan inisialisasi objek model Gaussian Naive Bayes

# %% [markdown]
# ##### **K-Nearest Neighbor**

# %% [markdown]
# K-nearest neighbors atau knn adalah algoritma yang berfungsi untuk melakukan klasifikasi suatu data berdasarkan data latih (train data), yang diambil dari k tetangga terdekatnya (nearest neighbors). Dengan k merupakan banyaknya tetangga terdekat.

# %%
knn = KNeighborsClassifier()

knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Syntax diatas digunakan untuk menginisialisasi dan melatih model klasifikasi K-Nearest Neighbors (KNN) menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label data pelatihan (y_train). Untuk outputnya menunjukkan inisialisasi objek model K-Nearest Neighbors (KNN)

# %% [markdown]
# ##### **Desicion Tree**

# %% [markdown]
# Decision Tree atau Pohon Keputusan merupakan algoritma model prediksi yang dapat digunakan untuk klasifikasi dan prediksi target.

# %%
dtc = DecisionTreeClassifier()

dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Syntax diatas digunakan untuk menginisialisasi dan melatih model Decision Tree Classifier (DTC) menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label data pelatihan (y_train). Untuk outputnya menunjukkan inisialisasi objek model Decision Tree Classifier (DTC).

# %% [markdown]
# ##### **Begins and Compare Predict**

# %%
gnb_pred = gnb.predict(x_test_norm)
gnb_proba = gnb.predict_proba(x_test_norm)
knn_pred = knn.predict(x_test_norm)
knn_proba = knn.predict_proba(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)
dtc_proba = dtc.predict_proba(x_test_norm)

# %% [markdown]
# Syntax diatas digunakan untuk membuat prediksi menggunakan model yang telah dilatih seperti Gaussian Naive Bayes, K-Nearest Neighbors, dan Decision Tree Classifier pada data pengujian yang telah dinormalisasi (x_test_norm).

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"])
knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"])
dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# Syntax diatas digunakan untuk menggabungkan data uji (x_test dan y_test) dengan prediksi yang dihasilkan oleh tiga model klasifikasi yang telah dilatih sebelumnya yaitu Gaussian Naive Bayes, K-Nearest Neighbors, dan Decision Tree Classifier.

# %%
combined_data.sample(10)
# Out:
#      price(in Rs.)  processor  ram  os  storage  display(in inch)    rating  \
# 126          62180          0    1   1        0             15.60  4.284884
# 242          48999          3    2   8        1             15.60  4.284884
# 101         189990         13    4   0        3             15.60  4.284884
# 156          97500          2    0   4        0             15.60  3.700000
# 193          88490         13    0   1        0             15.60  5.000000
# 40           36990          1    1   0        2             15.60  4.284884
# 284          55990         33    1   0        0             15.60  4.600000
# 89           27990          8    1   0        2             15.60  3.800000
# 107          28960         27    1   0        2             14.00  4.284884
# 267          42690          1    1   1        2             14.96  4.400000
#
#      no_of_ratings  no_of_reviews  PriceCategory  gnb_prediction  \
# 126      718.09157      83.898256              2               2
# ...

# %% [markdown]
# Syntax combined_data.sample(10) digunakan untuk mengambil contoh acak sebanyak 10 baris dari DataFrame combined_data. Ini membantu untuk melihat sebagian dari data yang telah digabungkan untuk memastikan bahwa penggabungan data telah dilakukan dengan benar.

# %%
# Evaluasi hasil prediksi Gaussian Naive Bayes
gnb_accuracy = accuracy_score(y_test, gnb_pred)
print("Gaussian Naive Bayes:", gnb_accuracy)

# Evaluasi hasil prediksi K-Nearest Neighbors
knn_accuracy = accuracy_score(y_test, knn_pred)
print("K-Nearest Neighbors:", knn_accuracy)

# Evaluasi hasil prediksi Decision Tree Classifier
dtc_accuracy = accuracy_score(y_test, dtc_pred)
print("Decision Tree Classifier:", dtc_accuracy)
# Out:
# Gaussian Naive Bayes: 0.8918918918918919
# K-Nearest Neighbors: 0.8648648648648649
# Decision Tree Classifier: 0.9966216216216216

# %% [markdown]
# ## **Visualisasi**

# %% [markdown]
# #### **Gaussian Naive Bayes**

# %%
actual_data = combined_data['PriceCategory']
gnb_predictions = combined_data['gnb_prediction']

df_actual = pd.DataFrame({'Category': 'Actual', 'PriceCategory': actual_data})
df_predicted = pd.DataFrame({'Category': 'GNB Predicted', 'PriceCategory': gnb_predictions})

df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(10, 6))
sns.countplot(data=df_combined, x='PriceCategory', hue='Category', palette=['slateblue', 'darkblue'])
plt.title('Comparison of Actual and GNB Predicted PriceCategory')
plt.xlabel('PriceCategory')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %% [markdown]
# Syntax di atas digunakan untuk membandingkan data aktual dan prediksi dari model GNB (Gaussian Naive Bayes) untuk kolom 'PriceCategory' menggunakan seaborn countplot. Dari hasil Output diatas menjelaskan bahwa :
# - Perbandingan Harga Aktual dan Prediksi GNB :
# Harga Aktual: Ditunjukkan dengan garis biru pada grafik.
# Harga Prediksi GNB: Ditunjukkan dengan garis merah pada grafik.
# - Harga Aktual lebih tinggi daripada Harga Prediksi GNB. Hal ini dapat terlihat dari garis biru yang selalu berada di atas garis ungu pada grafik.
# - Perbedaan harga antara Aktual dan Prediksi GNB bervariasi.
# - Untuk secara keseluruhan, model GNB tidak cukup akurat dalam memprediksi harga. Hal ini karena terlihat dari banyaknya perbedaan antara harga aktual dan prediksi GNB.

# %% [markdown]
# ##### **K-Nearest Neighbor**

# %%
actual_data = combined_data['PriceCategory']
knn_predictions = combined_data['knn_prediction']

df_actual = pd.DataFrame({'Category': 'Actual', 'PriceCategory': actual_data})
df_predicted = pd.DataFrame({'Category': 'KNN Predicted', 'PriceCategory': knn_predictions})

df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(10, 6))
sns.countplot(data=df_combined, x='PriceCategory', hue='Category', palette=['slateblue', 'darkblue'])
plt.title('Comparison of Actual and KNN Predicted PriceCategory')
plt.xlabel('PriceCategory')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %% [markdown]
# Syntax di atas digunakan untuk membandingkan data aktual dan prediksi dari model KNN (K-Nearest Neighbor) untuk kolom 'PriceCategory' menggunakan seaborn countplot. Dari hasil Output diatas menjelaskan bahwa :
# - Perbandingan Kategori Harga Aktual dan Prediksi KNN :
# Kategori Harga Aktual: Ditunjukkan dengan batang biru pada grafik.
# Kategori Harga Prediksi KNN: Ditunjukkan dengan batang merah pada grafik.
# - Model KNN cukup akurat dalam memprediksi kategori harga. Hal ini terlihat dari banyaknya kategori harga yang sama antara aktual dan prediksi KNN.
# Terdapat beberapa kesalahan prediksi pada kategori harga 0 dan 2. Pada kategori harga 0, model KNN memprediksi lebih banyak data daripada yang sebenarnya. Pada kategori harga 2, model KNN memprediksi lebih sedikit data daripada yang sebenarnya.

# %% [markdown]
# ##### **Decision Tree**

# %%
actual_data = combined_data['PriceCategory']
dtc_predictions = combined_data['dtc_prediction']

df_actual = pd.DataFrame({'Category': 'Actual', 'PriceCategory': actual_data})
df_predicted = pd.DataFrame({'Category': 'DTC Predicted', 'PriceCategory': dtc_predictions})

df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(10, 6))
sns.countplot(data=df_combined, x='PriceCategory', hue='Category', palette=['slateblue', 'darkblue'])
plt.title('Comparison of Actual and DTC Predicted PriceCategory')
plt.xlabel('PriceCategory')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %% [markdown]
# Syntax di atas digunakan untuk membandingkan data aktual dan prediksi dari model DTC (Decision Tree) untuk kolom 'PriceCategory' menggunakan seaborn countplot. Dari hasil Output diatas menjelaskan bahwa :
# - Perbandingan Kategori Harga Aktual dan Prediksi DTC :
# Kategori Harga Aktual: Ditunjukkan dengan batang biru pada grafik.
# Kategori Harga Prediksi DTC: Ditunjukkan dengan batang merah pada grafik.
# - Model DTC sangat akurat dalam memprediksi kategori harga. Hal ini terlihat dari banyaknya kategori harga yang sama antara aktual dan prediksi DTC.
# Terdapat beberapa kesalahan prediksi pada kategori harga 0 dan 2. Pada kategori harga 0, model DTC memprediksi lebih banyak data daripada yang sebenarnya. Pada kategori harga 2, model DTC memprediksi lebih sedikit data daripada yang sebenarnya.

# %% [markdown]
# # **Evaluate Result**

# %% [markdown]
# Tahap evaluasi dalam metodologi CRISP-DM adalah tahap di mana model atau solusi yang dikembangkan selama proses data mining dievaluasi untuk kelayakan dan kinerjanya dalam lingkungan produksi.

# %% [markdown]
# ### **Klasifikasi**

# %%
print(len(y_test))
print(len(gnb_pred))
# Out:
# 296
# 296

# %% [markdown]
# code diatas digunakan untuk mencetak lenght (jumlah elemen) dari vektor y_test dan gnb_pred. Berdasarkan output diatas, panjang y_test sebesar 296 dan panjang gnb_pred sebesar 296 juga.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
gnb_cm = confusion_matrix(y_test, gnb_pred)

negative_class = 0

TN = np.sum(np.delete(np.delete(gnb_cm, negative_class, axis=0), negative_class, axis=1))
FP = np.sum(np.delete(gnb_cm[:, negative_class], negative_class))
FN = np.sum(np.delete(gnb_cm[negative_class, :], negative_class))
TP = gnb_cm[negative_class, negative_class]

print('TN :', TN)
print('FP :', FP)
print('FN :', FN)
print('TP :', TP)
# Out:
# TN : 278
# FP : 1
# FN : 8
# TP : 9

# %% [markdown]
# Code di atas digunakan untuk menghitung True Negative (TN), False Positive (FP), False Negative (FN), dan True Positive (TP) dari confusion matrix yang dihasilkan oleh model Gaussian Naive Bayes (GNB) terhadap data uji.
# - **Penjelasan Output**
# - TN (True Negative): 271
# Ini adalah jumlah sampel yang benar-benar diklasifikasikan sebagai negatif oleh model. kelas negatif dalam kasus ini adalah kelas yang bukan kelas target yang diinginkan, dan model juga memprediksi bahwa mereka bukan kelas target yang diinginkan.
#
# - FP (False Positive): 8
# Ini adalah jumlah sampel yang salah diklasifikasikan sebagai positif oleh model kelas positif dalam kasus ini adalah kelas target yang diinginkan, meskipun sebenarnya mereka adalah kelas negatif.
#
# - FN (False Negative): 4
# Ini adalah jumlah sampel yang salah diklasifikasikan sebagai negatif oleh model, padahal seharusnya mereka adalah kelas positif.
#
# - TP (True Positive): 13
# Ini adalah jumlah sampel yang benar-benar diklasifikasikan sebagai positif oleh model dan model juga memprediksi dengan benar bahwa mereka adalah kelas target yang diinginkan.

# %%
acc = (TP + TN) / (TP + TN + FP + FN)
pre = TP / (TP + FP)
rec = TP / (TP + FN)
f1_score = (2 * pre * rec) / (pre + rec)

print('Accuracy :', acc)
print('Precession :', pre)
print('Recall :', rec)
print('F1_score :', f1_score)
# Out:
# Accuracy : 0.9695945945945946
# Precession : 0.9
# Recall : 0.5294117647058824
# F1_score : 0.6666666666666667

# %% [markdown]
# COde di atas menghitung beberapa matrix evaluasi kinerja model klasifikasi, berdasarkan nilai-nilai yang diambil dari matriks kebingungan yang telah dihitung sebelumnya.
# - Accuracy (Akurasi): Nilai akurasi adalah 0.9594, yang menunjukkan bahwa model mengklasifikasikan 95.94% dari seluruh sampel dengan benar.
#
# - Precision (Presisi): Nilai presisi adalah 0.6190, yang berarti 61.90% dari sampel yang diprediksi positif oleh model benar-benar positif.
#
# - Recall (Recall atau Sensitivitas): Nilai recall adalah 0.7647, yang menunjukkan bahwa model berhasil memprediksi 76.47% dari semua sampel yang sebenarnya positif.
#
# - F1 Score: Nilai F1-score adalah 0.6842, yang merupakan rata-rata harmonik dari presisi dan recall.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

gnb_cm = confusion_matrix(y_test, gnb_pred)
gnb_cm_display = ConfusionMatrixDisplay(gnb_cm).plot(ax=axes[0], cmap='inferno')
gnb_cm_display.ax_.set_title("Gaussian Naive Bayes")

knn_cm = confusion_matrix(y_test, knn_pred)
knn_cm_display = ConfusionMatrixDisplay(knn_cm).plot(ax=axes[1], cmap='inferno')
knn_cm_display.ax_.set_title("K Nearest Neighbor")

dtc_cm = confusion_matrix(y_test, dtc_pred)
dtc_cm_display = ConfusionMatrixDisplay(dtc_cm).plot(ax=axes[2], cmap='inferno')
dtc_cm_display.ax_.set_title("Decision Tree Classifier")

plt.show()

# %% [markdown]
# Code di atas bertujuan untuk membuat tiga plot confusion matrix dari tiga model klasifikasi yang berbeda (Gaussian Naive Bayes, K Nearest Neighbor, dan Decision Tree Classifier) dalam satu gambar.
#
# - **penjelasan output**:
#
# 1) **GNB**
# - Terdapat 13 prediksi label “cheap” yang sesuai dengan label “cheap” yang sebenarnya.
# - Terdapat 59 prediksi label “affordable” yang sesuai dengan label “affordable” yang sebenarnya,
# - Terdapat 7 prediksi label “affordable” yang tidak sesuai dengan true label “affordable” melainkan label “cheap”,
# - Terdapat 4 prediksi label “affordable” yang tidak sesuai dengan true label “affordable” melainkan label “expensive”.
# -  Terdapat 197 prediksi label “expensive” yang sesuai dengan label “expensive” yang sebenarnya,
# - Terdapat 11 prediksi label “expensive” yang tidak sesuai dengan true label “expensive” melainkan label “affordable”.
#
# 2) **KNN**
# - Terdapat 8 prediksi label “cheap” yang sesuai dengan label “cheap” yang sebenarnya.
# - Terdapat 9 prediksi label “cheap” yang salah diberi label “affordable”.
# - Terdapat 58 prediksi label “affordable” yang sesuai dengan label “affordable” yang sebenarnya.
# - Terdapat 2 prediksi label “affordable” yang salah diberi label “cheap”.
# - Terdapat 10 prediksi label “affordable” yang seharusnya “expensive” namun salah diberi label “cheap”.
# - Terdapat 205 prediksi label “expensive” yang sesuai dengan label “expensive” yang sebenarnya.
# - Terdapat 1 prediksi label “expensive” yang seharusnya “affordable” namun salah diberi label “expensive”.
#
# 3) **DTC**
# - Semua dari 17 prediksi label “cheap” sesuai dengan label “cheap” yang sebenarnya.
# - Terdapat 32 prediksi label “affordable” yang sesuai dengan label “affordable” yang sebenarnya.
# - Terdapat 16 prediksi label “expensive” yang sesuai dengan label “expensive” yang sebenarnya.
# - Terdapat 1 prediksi label “expensive” yang seharusnya “affordable” namun salah diberi label “expensive”.

# %% [markdown]
# Pemetaan dari Confusion Matrix 3x3 ke Confusion Matrix 2x2 diperlukan karena matrix ROC (Receiver Operating Characteristic) dan AUC (Area Under the Curve) umumnya digunakan untuk mengevaluasi model klasifikasi biner, di mana terdapat dua kelas: positif dan negatif. Berikut merupakan pemetaan dari Confusion Matrix 3x3 menjadi Confusion Matrix 2x2.

# %% [markdown]
# #### **GNB**

# %%
plt.figure(figsize=(20, 10))

class_names = [0,1,2]
matrix1 = gnb_cm
matrix2 = knn_cm
matrix3 = dtc_cm

TN_manual_cheap = matrix1[1, 1] + matrix1[1, 2] + matrix1[2, 1] + matrix1[2, 2]
TN_manual_affordable = matrix1[0, 0] + matrix1[0, 2] + matrix1[2, 0] + matrix1[2, 2]
TN_manual_expensive = matrix1[0, 0] + matrix1[0, 1] + matrix1[1, 0] + matrix1[1, 1]

# Menggabungkan plot untuk 'cheap' dengan GNB
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix1[0, 0], matrix1[0, 1] + matrix1[0, 2]],
                          [matrix1[1, 0] + matrix1[2, 0], TN_manual_cheap]],
                         index=['cheap', 'Non-cheap'], columns=['cheap', 'Non-cheap']), annot=True, fmt=".0f", cmap="Blues")
plt.title('GNB Confusion Matrix for cheap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'affordable' dengan GNB
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix1[1, 1], matrix1[1, 0] + matrix1[1, 2]],
                          [matrix1[0, 1] + matrix1[2, 1], TN_manual_affordable]],
                         index=['affordable', 'Non-affordable'], columns=['affordable', 'Non-affordable']), annot=True, fmt=".0f", cmap="Blues")
plt.title('GNB Confusion Matrix for affordable')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'expensive' dengan GNB
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix1[2, 2], matrix1[2, 0] + matrix1[2, 1]],
                          [matrix1[0, 2] + matrix1[1, 2], TN_manual_expensive]],
                         index=['expensive', 'Non-expensive'], columns=['expensive', 'Non-expensive']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('GNB Confusion Matrix for expensive')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Output diatas menampilkan tiga Confusion Matrix yang menggambarkan kinerja dari sebuah klasifikasi menggunakan metode Gaussian Naive Bayes (GNB). Klasifikasi ini bertujuan untuk memprediksi apakah suatu item termasuk dalam kategori murah (cheap), terjangkau (affordable), atau mahal (expensive).
# - **Penjelasan Output**:
#
# 1) Cheap (Murah):
# *   Terdapat 276 item yang terklasifikasikan dengan benar sebagai non-cheap.
# *   Terdapat 13 item yang terklasifikasikan dengan benar sebagai cheap.
#
# 2) Affordable (Terjangkau):
# *   Terdapat 211 item yang terklasifikasikan dengan benar sebagai non-affordable.
# *   Terdapat 59 item yang terklasifikasikan dengan benar sebagai affordable.
#
# 3) Expensive:
# *   Terdapat 197 item yang terklasifikasikan dengan benar sebagai expensive.
# *   Terdapat 83 item yang terklasifikasikan dengan benar sebagai non-expensive.

# %% [markdown]
# #### **KNN**

# %%
plt.figure(figsize=(20, 10))

class_names = [0,1,2]
matrix1 = gnb_cm
matrix2 = knn_cm
matrix3 = dtc_cm

TN_manual_cheap = matrix2[1, 1] + matrix2[1, 2] + matrix2[2, 1] + matrix2[2, 2]
TN_manual_affordable = matrix2[0, 0] + matrix2[0, 2] + matrix2[2, 0] + matrix2[2, 2]
TN_manual_expensive = matrix2[0, 0] + matrix2[0, 1] + matrix2[1, 0] + matrix2[1, 1]

# Menggabungkan plot untuk 'cheap' dengan KNN
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix2[0, 0], matrix2[0, 1] + matrix2[0, 2]],
                          [matrix2[1, 0] + matrix2[2, 0], TN_manual_cheap]],
                         index=['cheap', 'Non-cheap'], columns=['cheap', 'Non-cheap']), annot=True, fmt=".0f", cmap="Blues")
plt.title('KNN Confusion Matrix for cheap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'affordable' dengan KNN
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix2[1, 1], matrix2[1, 0] + matrix2[1, 2]],
                          [matrix2[0, 1] + matrix2[2, 1], TN_manual_affordable]],
                         index=['affordable', 'Non-affordable'], columns=['affordable', 'Non-affordable']), annot=True, fmt=".0f", cmap="Blues")
plt.title('KNN Confusion Matrix for affordable')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'expensive' dengan KNN
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix2[2, 2], matrix2[2, 0] + matrix2[2, 1]],
                          [matrix2[0, 2] + matrix2[1, 2], TN_manual_expensive]],
                         index=['expensive', 'Non-expensive'], columns=['expensive', 'Non-expensive']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('KNN Confusion Matrix for expensive')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Output diatas menampilkan tiga Confusion Matrix yang menggambarkan kinerja dari sebuah klasifikasi menggunakan metode K Nearest Neighbor (KNN). Klasifikasi ini bertujuan untuk memprediksi apakah suatu item termasuk dalam kategori murah (cheap), terjangkau (affordable), atau mahal (expensive).
# - **Penjelasan Output**
#
# 1) Cheap (Murah):
# *   276 item terklasifikasikan dengan benar sebagai non-cheap.
# *   8 item terklasifikasikan dengan benar sebagai cheap.
#
# 2) Affordable (Terjangkau):
# *   214 item terklasifikasikan dengan benar sebagai non-affordable.
# *   58 item terklasifikasikan dengan benar sebagai affordable.
#
# 3) Expensive (Mahal):
# *   205 item terklasifikasikan dengan benar sebagai expensive.
# *   77 item terklasifikasikan dengan benar sebagai non-expensive.

# %% [markdown]
# #### **DTC**

# %%
plt.figure(figsize=(20, 10))

class_names = [0,1,2]
matrix1 = gnb_cm
matrix2 = knn_cm
matrix3 = dtc_cm

TN_manual_cheap = matrix3[1, 1] + matrix3[1, 2] + matrix3[2, 1] + matrix3[2, 2]
TN_manual_affordable = matrix3[0, 0] + matrix3[0, 2] + matrix3[2, 0] + matrix3[2, 2]
TN_manual_expensive = matrix3[0, 0] + matrix3[0, 1] + matrix3[1, 0] + matrix3[1, 1]

# Menggabungkan plot untuk 'cheap' dengan DTC
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix3[0, 0], matrix3[0, 1] + matrix3[0, 2]],
                          [matrix3[1, 0] + matrix3[2, 0], TN_manual_cheap]],
                         index=['cheap', 'Non-cheap'], columns=['cheap', 'Non-cheap']), annot=True, fmt=".0f", cmap="Blues")
plt.title('DTC Confusion Matrix for cheap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'affordable' dengan DTC
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix3[1, 1], matrix3[1, 0] + matrix3[1, 2]],
                          [matrix3[0, 1] + matrix3[2, 1], TN_manual_affordable]],
                         index=['affordable', 'Non-affordable'], columns=['affordable', 'Non-affordable']), annot=True, fmt=".0f", cmap="Blues")
plt.title('DTC Confusion Matrix for affordable')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'expensive' dengan DTC
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix3[2, 2], matrix3[2, 0] + matrix3[2, 1]],
                          [matrix3[0, 2] + matrix3[1, 2], TN_manual_expensive]],
                         index=['expensive', 'Non-expensive'], columns=['expensive', 'Non-expensive']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('DTC Confusion Matrix for expensive')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Output di atas menampilkan tiga Confusion Matrix yang menggambarkan kinerja dari sebuah klasifikasi menggunakan metode Decision Tree (DTC). Klasifikasi ini bertujuan untuk memprediksi apakah suatu item termasuk dalam kategori murah (cheap), terjangkau (affordable), atau mahal (expensive).
#
# - **Penjelasan Output**
#
# 1) Cheap (Murah):
# *   279 item terklasifikasikan dengan benar sebagai non-cheap.
# *   17 item terklasifikasikan dengan benar sebagai cheap.
#
# 2) Affordable (Terjangkau):
# *   225 item terklasifikasikan dengan benar sebagai non-affordable.
# *   70 item terklasifikasikan dengan benar sebagai affordable.
#
# 3) Expensive (Mahal):
# - 208 item terklasifikasikan dengan benar sebagai expensive.
# - 87 item terklasifikasikan dengan benar sebagai non-expensive.

# %%
def calculate_tpr_fpr(y_real, y_pred):

    cm = confusion_matrix(y_real, y_pred)
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]

    tpr =  TP/(TP + FN)
    fpr = 1 - TN/(TN+FP)

    return tpr, fpr

# %% [markdown]
# Fungsi code calculate_tpr_fpr digunakan untuk menghitung nilai True Positive Rate (TPR) dan False Positive Rate (FPR) dari hasil prediksi model klasifikasi. code ini berguna untuk mengevaluasi kinerja model klasifikasi biner.

# %%
def get_all_roc_coordinates(y_real, y_proba):

    tpr_list = [0]
    fpr_list = [0]
    for i in range(len(y_proba)):
        threshold = y_proba[i]
        y_pred = y_proba >= threshold
        tpr, fpr = calculate_tpr_fpr(y_real, y_pred)
        tpr_list.append(tpr)
        fpr_list.append(fpr)
    return tpr_list, fpr_list

# %% [markdown]
# Code diatas digunakan untuk menghasilkan semua koordinat yang diperlukan untuk membangun kurva Receiver Operating Characteristic (ROC). ROC adalah grafik yang menunjukkan kinerja model klasifikasi di berbagai nilai ambang (threshold) dengan membandingkan TPR (True Positive Rate) dengan FPR (False Positive Rate) tersebut.

# %%
def plot_roc_curve(tpr, fpr, scatter = True, ax = None):

    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()

    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = [0, 1], y = [0, 1], color = 'green', ax = ax)
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %% [markdown]
# Fungsi plot_roc_curve digunakan untuk menggambar kurva ROC (Receiver Operating Characteristic) dari nilai True Positive Rate (TPR) dan False Positive Rate (FPR) yang diberikan.

# %%
classes = gnb.classes_
classes
# Out:
# array([0, 1, 2])

# %% [markdown]
# Variabel classes berisi kelas-kelas yang telah dipelajari oleh model Gaussian Naive Bayes (GNB).

# %%
from sklearn.metrics import roc_auc_score

plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_gnb = {}
PriceCategory_names = ['Cheap', 'Affordable', 'Expensive']

classes = y_test['PriceCategory'].unique()

for i in range(len(classes)):
    c = classes[i]

    df_aux = pd.DataFrame(x_test_norm).copy()
    df_aux['PriceCategory'] = [1 if y == c else 0 for y in y_test['PriceCategory']]
    df_aux['prob'] = gnb_proba[:, i]
    df_aux = df_aux.reset_index(drop=True)

    ax = plt.subplot(2, 3, i+1)
    sns.histplot(x="prob", data=df_aux, hue='PriceCategory', color='b', ax=ax, bins=bins)
    ax.set_title(PriceCategory_names[i])
    ax.legend([f"PriceCategory: {PriceCategory_names[i]}", f"Non-{PriceCategory_names[i]}"])
    ax.set_xlabel(f"P(x = {PriceCategory_names[i]})")

    ax_bottom = plt.subplot(2, 3, i+4)
    tpr, fpr = get_all_roc_coordinates(df_aux['PriceCategory'], df_aux['prob'])
    plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
    ax_bottom.set_title("ROC Curve OvR")

    roc_auc_ovr_gnb[c] = roc_auc_score(df_aux['PriceCategory'], df_aux['prob'])

plt.suptitle('Probability Distributions and ROC Curves for Gaussian Naive Bayes')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fungsi code di atas adalah untuk menghasilkan plot distribusi probabilitas dan kurva ROC (Receiver Operating Characteristic) untuk setiap kelas (one vs rest) pada model Gaussian Naive Bayes (GNB).

# %%
classes = knn.classes_
classes
# Out:
# array([0, 1, 2])

# %% [markdown]
# Variabel classes berisi kelas-kelas yang telah dipelajari oleh model K-Nearest Neighbor (KNN).

# %%
from sklearn.metrics import roc_auc_score

plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_knn = {}
PriceCategory_names = ['Cheap', 'Affordable', 'Expensive']

for i in range(len(classes)):
    c = classes[i]

    df_aux = pd.DataFrame(x_test_norm).copy()
    df_aux['PriceCategory'] = [1 if y == c else 0 for y in y_test['PriceCategory']]
    df_aux['prob'] = knn_proba[:, i]
    df_aux = df_aux.reset_index(drop=True)

    ax = plt.subplot(2, 3, i+1)
    sns.histplot(x="prob", data=df_aux, hue='PriceCategory', color='b', ax=ax, bins=bins)
    ax.set_title(PriceCategory_names[i])
    ax.legend([f"PriceCategory: {PriceCategory_names[i]}", f"Non-{PriceCategory_names[i]}"])
    ax.set_xlabel(f"P(x = {PriceCategory_names[i]})")

    ax_bottom = plt.subplot(2, 3, i+4)
    tpr, fpr = get_all_roc_coordinates(df_aux['PriceCategory'], df_aux['prob'])
    plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
    ax_bottom.set_title("ROC Curve OvR")

    roc_auc_ovr_knn[c] = roc_auc_score(df_aux['PriceCategory'], df_aux['prob'])

plt.suptitle('Probability Distributions and ROC Curves for K-Nearest Neighbor')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fungsi code di atas adalah untuk menghasilkan plot distribusi probabilitas dan kurva ROC (Receiver Operating Characteristic) untuk setiap kelas (one vs rest) pada K-Nearest Neighbor (KNN).

# %%
classes = dtc.classes_
classes
# Out:
# array([0, 1, 2])

# %% [markdown]
# Variabel classes berisi kelas-kelas yang telah dipelajari oleh model Decision Tree (DTC).

# %%
from sklearn.metrics import roc_auc_score

plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_dtc = {}
PriceCategory_names = ['Cheap', 'Affordable', 'Expensive']

for i in range(len(classes)):
    c = classes[i]

    df_aux = pd.DataFrame(x_test_norm).copy()
    df_aux['PriceCategory'] = [1 if y == c else 0 for y in y_test['PriceCategory']]
    df_aux['prob'] = dtc_proba[:, i]
    df_aux = df_aux.reset_index(drop=True)

    ax = plt.subplot(2, 3, i+1)
    sns.histplot(x="prob", data=df_aux, hue='PriceCategory', color='b', ax=ax, bins=bins)
    ax.set_title(PriceCategory_names[i])
    ax.legend([f"PriceCategory: {PriceCategory_names[i]}", f"Non-{PriceCategory_names[i]}"])
    ax.set_xlabel(f"P(x = {PriceCategory_names[i]})")

    ax_bottom = plt.subplot(2, 3, i+4)
    tpr, fpr = get_all_roc_coordinates(df_aux['PriceCategory'], df_aux['prob'])
    plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
    ax_bottom.set_title("ROC Curve OvR")

    roc_auc_ovr_dtc[c] = roc_auc_score(df_aux['PriceCategory'], df_aux['prob'])

plt.suptitle('Probability Distributions and ROC Curves for Decision Tree')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fungsi code di atas adalah untuk menghasilkan plot distribusi probabilitas dan kurva ROC (Receiver Operating Characteristic) untuk setiap kelas (one vs rest) pada Decision Tree (DTC).

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Gaussian Naive Bayes
gnb_accuracy = accuracy_score(y_test, gnb_pred)
gnb_precision = precision_score(y_test, gnb_pred, average='macro')
gnb_recall = recall_score(y_test, gnb_pred, average='macro')
gnb_f1 = f1_score(y_test, gnb_pred, average='macro')

print("Gaussian Naive Bayes:")
print("Accuracy:", gnb_accuracy)
print("Precision:", gnb_precision)
print("Recall:", gnb_recall)
print("F1-score:", gnb_f1)
print()

# K Nearest Neighbor
knn_accuracy = accuracy_score(y_test, knn_pred)
knn_precision = precision_score(y_test, knn_pred, average='macro')
knn_recall = recall_score(y_test, knn_pred, average='macro')
knn_f1 = f1_score(y_test, knn_pred, average='macro')

print("K Nearest Neighbor:")
print("Accuracy:", knn_accuracy)
print("Precision:", knn_precision)
print("Recall:", knn_recall)
print("F1-score:", knn_f1)
print()

# Decision Tree Classifier
dtc_accuracy = accuracy_score(y_test, dtc_pred)
dtc_precision = precision_score(y_test, dtc_pred, average='macro')
dtc_recall = recall_score(y_test, dtc_pred, average='macro')
dtc_f1 = f1_score(y_test, dtc_pred, average='macro')

print("Decision Tree Classifier:")
print("Accuracy:", dtc_accuracy)
print("Precision:", dtc_precision)
print("Recall:", dtc_recall)
print("F1-score:", dtc_f1)
print()
# Out:
# Gaussian Naive Bayes:
# Accuracy: 0.8918918918918919
# Precision: 0.8802028218694886
# Recall: 0.7668556417782425
# F1-score: 0.8074323062558357
#
# K Nearest Neighbor:
# Accuracy: 0.8648648648648649
# Precision: 0.7628718940907996
# Recall: 0.7139144653076541
# F1-score: 0.734972568102667
#
# Decision Tree Classifier:
# Accuracy: 0.9966216216216216
# Precision: 0.9953051643192489
# Recall: 0.9984051036682615
# F1-score: 0.9968365732945559

# %% [markdown]
# Fungsi code di atas digunakan untuk menghitung dan mencetak nilai matrix evaluasi kinerja model klasifikasi seperti akurasi, presisi, recall, dan F1-score untuk tiga model klasifikasi yang berbeda: Gaussian Naive Bayes, K Nearest Neighbor, dan Decision Tree Classifier.

# %% [markdown]
# ## **Review Proses**

# %% [markdown]
# ### **Cross Validation**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score

# Inisialisasi model
models = [gnb, knn, dtc]
model_names = ['Gaussian Naive Bayes', 'K-Nearest Neighbors', 'Decision Tree Classifier']

# Lakukan validasi silang untuk setiap model
cv_scores = []
for model in models:
    scores = cross_val_score(model, x_train_norm, y_train, cv=5)
    cv_scores.append(scores)

# Buat dataframe dari hasil validasi silang
df_cv_scores = pd.DataFrame(cv_scores, index=model_names).T

# Tampilkan visualisasi hasil validasi silang dengan lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cv_scores, markers=True)
plt.title('Cross-Validation Scores for Different Models')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title='Model', loc='lower right')
plt.xticks(ticks=range(5), labels=['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5'])
plt.show()

# %% [markdown]
# Code di atas digunakan untuk melakukan validasi silang (cross-validation) pada beberapa model klasifikasi dan memvisualisasikan hasilnya menggunakan seaborn dan matplotlib.
#
# - **Penjelasan Output**
#
# 1) Decision Tree Classifier memiliki performa terbaik dibandingkan dengan dua model lainnya, yaitu Gaussian Naive Bayes dan K-Nearest Neighbors karena  ditunjukkan dengan skor cross-validation rata-rata yang lebih tinggi pada Decision Tree Classifier.
#
# 2) Gaussian Naive Bayes memiliki performa yang lebih rendah dibandingkan dengan Decision Tree Classifier dan K-Nearest Neighbors karena ditunjukkan dengan skor cross-validation rata-rata yang paling rendah pada Gaussian Naive Bayes.
#
# 3) K-Nearest Neighbors memiliki performa yang berada di tengah-tengah antara Decision Tree Classifier dan Gaussian Naive Bayes. Hal ini ditunjukkan dengan skor cross-validation rata-rata yang berada di antara kedua model tersebut.

# %% [markdown]
# ### **Tuning Hypermater**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

grid_search = GridSearchCV(estimator=gnb, param_grid=param_grid, cv=5)

grid_search.fit(x_train_norm, y_train)

print("Parameter terbaik:", grid_search.best_params_)

y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

acc_before_tuning = gnb.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'var_smoothing': 1.5199110829529332e-05}
# Akurasi sebelum tuning: 0.8918918918918919
# Akurasi setelah tuning: 0.8918918918918919

# %% [markdown]
# Fungsi dari code di atas adalah untuk melakukan tuning parameter pada model Gaussian Naive Bayes menggunakan metode Grid Search CV. Grid Search CV adalah metode yang digunakan untuk mencari parameter terbaik untuk suatu model dengan mencoba semua kombinasi parameter yang mungkin dari suatu grid parameter yang telah ditentukan.
#
# - **Penjelasan Output**
#
# Hasil dari pencarian parameter terbaik adalah {'var_smoothing': 0.005336699231206307}. Ini berarti nilai terbaik untuk parameter var_smoothing adalah sekitar 0.005336699231206307. Parameter var_smoothing adalah parameter smoothing yang digunakan dalam Gaussian Naive Bayes untuk menghindari nilai probabilitas nol saat mengestimasi distribusi Gaussian.
#
# - Akurasi sebelum tuning: Akurasi model Gaussian Naive Bayes sebelum proses tuning parameter adalah 0.9087837837837838 atau sekitar 90.88%.
#
# - Akurasi setelah tuning: Akurasi model Gaussian Naive Bayes setelah proses tuning parameter adalah 0.8986486486486487 atau sekitar 89.86%.

# %% [markdown]
# ### **Feature Selection**

# %%
x_train = x_train.iloc[:, [0, 1, 2, 3, 4, 5]]

# %% [markdown]
# Code diatas menghasilkan data latih baru (x_train) yang hanya terdiri dari kolom-kolom dengan indeks 0 hingga 5 dari data latih awal.

# %%
x_train_norm = x_train_norm[:, [0, 1, 2, 3, 4, 5]]

# %% [markdown]
# Code diatas menghasilkan data latih baru yang dinormalisasi (x_train_norm) yang hanya terdiri dari fitur-fitur dengan indeks 0 hingga 5 dari data latih yang sudah dinormalisasi sebelumnya.

# %%
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt

# Pilih fitur terbaik dengan SelectKBest
selector = SelectKBest(score_func=chi2, k=5)
selector.fit(x_train_norm, y_train)

# Ambil indeks fitur terbaik
selected_feature_indices = selector.get_support(indices=True)

# Ambil nama fitur yang terpilih
selected_feature_names = x_train.columns[selected_feature_indices]

# Filter data training dan testing hanya untuk fitur-fitur terpilih
x_train_selected = x_train[selected_feature_names]
x_test_selected = x_test[selected_feature_names]

# Plot ranking fitur
feature_ranks = selector.scores_
feature_ranks_df = pd.DataFrame({'Feature': x_train.columns, 'Rank': feature_ranks})
feature_ranks_df = feature_ranks_df.sort_values(by='Rank', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_ranks_df['Feature'], feature_ranks_df['Rank'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Feature')
plt.title('Feature Ranking')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Code di atas bertujuan untuk melakukan seleksi fitur menggunakan metode SelectKBest dengan skor chi-squared (chi2) untuk kelas target yang berupa data kategorikal.
#
# - **Penjelasan Output**
#
# 1. Fitur penting:
#
#   Fitur dengan peringkat tinggi (misalnya, "harga (dalam Rp)") dianggap paling relevan dan penting.
#
# 2. Fitur tidak penting:
#
#   Fitur dengan peringkat rendah (misalnya, "Unnamed: 0") kemungkinan besar tidak berkontribusi signifikan dan bisa dihapuskan.

# %% [markdown]
# ### **Determine Next Step**

# %% [markdown]
# 1. **Pemilihan Model Terbaik:**
# Dalam dataset yang saya miliki, dapat diputuskan bahwa Decision Tree Classifier  yang paling cocok untuk Digunakan karena memiliki nilai akurasi tertinggi daripada kedua model yang lain
#
# 2. **Fine Tunning Model:**
# Evaluasi performa model : mempertimbangkan evaluasi lebih lanjut terhadap kinerja model setelah proses tuning, eksplorasi parameter lainnya, penyesuaian metode preprocessing data, dan juga membandingkan dengan model lain untuk memastikan bahwa model yang dipilih memenuhi kebutuhan analisis dataset yang saya punya
#
# 3. **Menganalisis Fitur Optimal:**
#  Diketahui kolom Price in RS memiliki peringkat tertinggi dalam barchart korelasi dengan kolom target. Oleh karena itu, langkah selanjutnya adalah menganalisis lebih lanjut fitur tersebut dan bagaimana pengaruhnya terhadap kolom target. Selain itu, bisa juga dilakukan analisis terhadap fitur lainnya untuk melihat kontribusinya dalam dataset yang saya miliki
#
# 4. **Evaluasi dan Peningkatan Lanjutan:**
# Melakukan evaluasi lebih lanjut terhadap model yang dipilih dan memantau kinerja model dan memperbarui atau meningkatkan model jika ada perubahan kebutuhan analisis dataset
#
# 5. **Menganalisis dan Memahami Performa Model**
#  Setelah melakukan evaluasi, dapat disimpulkan bahwa model klasifikasi menggunakan algoritma Decision Tree adalah algoritma yang optimal, karena beberapa hal berikut :
#
# - Accuracy: 0.9087837837837838
#
# - Precision: 0.7988148062774929
#
# - Recall: 0.8500489190891668
#
# - F1-score: 0.8215435268387772
#
#   matriks tersebut memiliki nilai yang sangat tinggi, yang mungkin menunjukkan kinerja yang sangat baik pada data yang digunakan untuk evaluasi.
#
#  Dari seluruh evaluation yang telah dilakukan berkesimpulan bahwa angka yang stabil dan analisis dapat dilanjutkan karena sudah mendapat algoritma yang optimal dari model Decision Tree (DTC)

# %%
x_test
# Out:
#      price(in Rs.)  processor  ram  os  storage  display(in inch)    rating  \
# 0           249900         26   14   3        0              16.0  4.284884
# 1           229990         15    8   1        4              16.0  4.284884
# 2            36890          7    1   1        2              14.0  4.284884
# 3           218290         13    4   0        3              16.0  4.284884
# 4            36890          7    1   1        2              14.0  4.284884
# ..             ...        ...  ...  ..      ...               ...       ...
# 291          47039         11    1   1        0              15.6  4.300000
# 292          52890          0    0   0        0              15.6  4.500000
# 293          37500          1    1   1        1              15.6  4.400000
# 294          71999          2    1   0        3              15.6  4.284884
# 295          37500          1    1   1        1              15.6  4.400000
#
#      no_of_ratings  no_of_reviews
# ...

# %%
x_test
# Out:
#      price(in Rs.)  processor  ram  os  storage  display(in inch)    rating  \
# 0           249900         26   14   3        0              16.0  4.284884
# 1           229990         15    8   1        4              16.0  4.284884
# 2            36890          7    1   1        2              14.0  4.284884
# 3           218290         13    4   0        3              16.0  4.284884
# 4            36890          7    1   1        2              14.0  4.284884
# ..             ...        ...  ...  ..      ...               ...       ...
# 291          47039         11    1   1        0              15.6  4.300000
# 292          52890          0    0   0        0              15.6  4.500000
# 293          37500          1    1   1        1              15.6  4.400000
# 294          71999          2    1   0        3              15.6  4.284884
# 295          37500          1    1   1        1              15.6  4.400000
#
#      no_of_ratings  no_of_reviews
# ...

# %%
import pickle

pickle.dump(gnb, open('gnb.pkl', 'wb'))

# %%
x_test['display(in inch)'].describe()
# Out:
# count    296.000000
# mean      15.164392
# std        1.514218
# min       11.600000
# 25%       14.000000
# 50%       15.600000
# 75%       15.600000
# max       35.000000
# Name: display(in inch), dtype: float64
